# %%
import pandas as pd
from matplotlib.ticker import ScalarFormatter

d = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
d_eu = d[d['Country/Region'].isin(['Germany','Spain','Italy','France','Portugal','Austria','Switzerland','Netherlands','Belgium','Luxembourg','Denmark']) & d['Province/State'].isnull()]
d_us = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv')
pop_data = pd.read_csv('https://stats.oecd.org/sdmx-json/data/DP_LIVE/.POP.TOT.MLN_PER.A/OECD?contentType=csv&detail=code&separator=comma&csv-lang=en&startPeriod=2018')
columns = ['319 Mil = DE,FR,IT,ES,NL,BE,PO,AU,CH,DK,LU','327 Mil in US']
eu_series = d_eu.iloc[:,4:].sum()
us_series = d_us.iloc[:,12:].sum()

# %%
pop_data
# Out:
#    LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME        Value  \
# 0       AUS       POP     TOT  MLN_PER         A  2018    24.992860
# 1       AUT       POP     TOT  MLN_PER         A  2018     8.837707
# 2       BEL       POP     TOT  MLN_PER         A  2018    11.403740
# 3       CAN       POP     TOT  MLN_PER         A  2018    37.058856
# 4       CZE       POP     TOT  MLN_PER         A  2018    10.626430
# 5       DNK       POP     TOT  MLN_PER         A  2018     5.789957
# 6       FIN       POP     TOT  MLN_PER         A  2018     5.515525
# 7       FRA       POP     TOT  MLN_PER         A  2018    66.941698
# 8       DEU       POP     TOT  MLN_PER         A  2018    82.914191
# 9       GRC       POP     TOT  MLN_PER         A  2018    10.725886
# 10      HUN       POP     TOT  MLN_PER         A  2018     9.767600
# 11      ISL       POP     TOT  MLN_PER         A  2018     0.352722
# 12      IRL       POP     TOT  MLN_PER         A  2018     4.857015
# 13      ITA       POP     TOT  MLN_PER         A  2018    60.421797
# 14      JPN       POP     TOT  MLN_PER         A  2018   126.443180
# 15      KOR       POP     TOT  MLN_PER         A  2018    51.635256
# 16      LUX       POP     TOT  MLN_PER         A  2018     0.607950
# 17      MEX       POP     TOT  MLN_PER         A  2018   125.327797
# 18      NLD       POP     TOT  MLN_PER         A  2018    17.231622
# 19      NZL       POP     TOT  MLN_PER         A  2018     4.885500
# 20      NOR       POP     TOT  MLN_PER         A  2018     5.311916
# 21      POL       POP     TOT  MLN_PER         A  2018    38.413139
# 22      PRT       POP     TOT  MLN_PER         A  2018    10.283822
# 23      SVK       POP     TOT  MLN_PER         A  2018     5.446771
# 24      ESP       POP     TOT  MLN_PER         A  2018    46.733038
# 25      SWE       POP     TOT  MLN_PER         A  2018    10.175214
# 26      CHE       POP     TOT  MLN_PER         A  2018     8.513227
# 27      TUR       POP     TOT  MLN_PER         A  2018    81.407211
# 28      GBR       POP     TOT  MLN_PER         A  2018    66.435550
# 29      USA       POP     TOT  MLN_PER         A  2018   327.167434
# 30      BRA       POP     TOT  MLN_PER         A  2018   208.494900
# 31      CHL       POP     TOT  MLN_PER         A  2018    18.751405
# 32      COL       POP     TOT  MLN_PER         A  2018    49.834240
# 33      EST       POP     TOT  MLN_PER         A  2018     1.321977
# 34      ISR       POP     TOT  MLN_PER         A  2018     8.872943
# 35      RUS       POP     TOT  MLN_PER         A  2018   144.491104
# 36      SVN       POP     TOT  MLN_PER         A  2018     2.070050
# 37      CHN       POP     TOT  MLN_PER         A  2018  1415.045928
# 38      IND       POP     TOT  MLN_PER         A  2018  1354.051854
# 39      IDN       POP     TOT  MLN_PER         A  2018   265.015300
# 40      ZAF       POP     TOT  MLN_PER         A  2018    57.725606
# 41     EU28       POP     TOT  MLN_PER         A  2018   513.179223
# 42     OECD       POP     TOT  MLN_PER         A  2018  1301.969697
# 43      LVA       POP     TOT  MLN_PER         A  2018     1.927170
# 44      ARG       POP     TOT  MLN_PER         A  2018    44.494502
# 45      BGR       POP     TOT  MLN_PER         A  2018     7.025037
# 46      CRI       POP     TOT  MLN_PER         A  2018     5.003402
# 47      HRV       POP     TOT  MLN_PER         A  2018     4.080666
# 48      CYP       POP     TOT  MLN_PER         A  2018     0.869006
# 49      LTU       POP     TOT  MLN_PER         A  2018     2.801541
# 50      MLT       POP     TOT  MLN_PER         A  2018     0.483793
# 51      ROU       POP     TOT  MLN_PER         A  2018    19.471332
# 52      SAU       POP     TOT  MLN_PER         A  2018    33.413660
# 53      SGP       POP     TOT  MLN_PER         A  2018     3.994283
# 54      WLD       POP     TOT  MLN_PER         A  2018  7632.819325
# 55      G20       POP     TOT  MLN_PER         A  2018  4809.944671
#
#     Flag Codes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         NaN
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51         NaN
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN

# %%
combined_date = eu_series.to_frame(name='EU').join(us_series.to_frame(name='US'))
ax = combined_date.iloc[24:].plot.line(logy=True,grid = True)
ax.legend(columns)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())

# %%
starting = 80
combined_cases = pd.concat([eu_series[eu_series > starting].reset_index(drop=True),us_series[us_series > starting].reset_index(drop=True)],axis=1,sort=False)
combined_cases.columns = columns
ax = combined_cases.plot.line(logy=True,grid = True)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())

# %%
roll_length = 5
combined_cases_inc = combined_cases.diff().fillna(combined_cases).rolling(roll_length).mean()
combined_cases_inc.iloc[roll_length-1:].plot.line(logy=True,title='Daily new cases rolling {} days average'.format(roll_length),grid=True,colormap='Paired',yticks=[100,1000])

# %%
combined_cases_inc
# Out:
#     319 Mil = DE,FR,IT,ES,NL,BE,PO,AU,CH,DK,LU  327 Mil in US
# 0                                          NaN            NaN
# 1                                          NaN            NaN
# 2                                          NaN            NaN
# 3                                          NaN            NaN
# 4                                          NaN            NaN
# 5                                          NaN            NaN
# 6                                     7.857143       4.000000
# 7                                    10.428571       3.000000
# 8                                    14.142857       4.000000
# 9                                    19.857143       4.857143
# 10                                   27.142857       5.000000
# 11                                   32.142857       5.571429
# 12                                   53.000000       8.857143
# 13                                   66.000000      11.285714
# 14                                   89.142857      15.857143
# 15                                  118.714286      24.142857
# 16                                  112.571429      30.000000
# 17                                  185.285714      38.000000
# 18                                  216.000000      52.428571
# 19                                  262.142857      66.857143
# 20                                  314.000000      85.571429
# 21                                  369.857143     114.142857
# 22                                  420.714286     142.857143
# 23                                  533.285714     189.000000
# 24                                  614.857143     244.000000
# 25                                  771.000000     291.428571
# 26                                  882.428571     346.571429
# 27                                 1021.857143     452.428571
# 28                                 1172.714286     545.000000
# 29                                 1371.428571     673.857143
# 30                                 1552.571429     786.571429
# 31                                 1723.142857     911.571429
# 32                                 1870.571429    1021.714286
# 33                                 2014.571429    1115.000000
# 34                                 2170.142857            NaN
# 35                                 2323.142857            NaN
# 36                                 2422.857143            NaN
# 37                                 2659.428571            NaN
# 38                                 2798.571429            NaN
# 39                                 2899.714286            NaN
# 40                                 2901.571429            NaN
# 41                                 2935.571429            NaN
